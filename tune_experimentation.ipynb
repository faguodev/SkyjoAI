# %%
from ray import tune, train, init, shutdown
from ray.tune.registry import register_env
from ray.rllib.env.wrappers.pettingzoo_env import PettingZooEnv
from ray.rllib.algorithms.ppo import PPOConfig
from ray.tune.stopper import MaximumIterationStopper

from environment.skyjo_env import env as skyjo_env
from ray.rllib.algorithms.callbacks import DefaultCallbacks
import logging
import numpy as np
import os
import json

from models.action_mask_model import TorchActionMaskModel

# %%
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


class RewardDecayCallback(DefaultCallbacks):
    def on_train_result(self, *, algorithm, result, **kwargs):
        # Decay the reward scaling factor over training iterations
        action_reward_decay = max(0.05, 1.0 - result["training_iteration"] * 0.005)
        # env = algorithm.workers.local_worker().env
        # env = algorithm.workers.local_env_runner.env
        algorithm.config.env_config["action_reward_decay"] = action_reward_decay
        logger.info(action_reward_decay)


class SkyjoLoggingCallbacks(DefaultCallbacks):
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        """
        This is called at the end of each episode. We grab
        the final card sum from the `info` dict for each agent
        and log it as a custom metric.
        """
        for agent_id in episode.get_agents():
            info = episode.last_info_for(agent_id)
            if info is not None and "final_sum_of_revealed_cards" in info:
                metric_name = f"final_sum_of_revealed_cards_{agent_id}"
                episode.custom_metrics[metric_name] = info["final_sum_of_revealed_cards"]
            if info is not None and "n_hidden_cards" in info:
                metric_name = f"n_hidden_cards_{agent_id}"
                episode.custom_metrics[metric_name] = info["n_hidden_cards"]

skyjo_config = {
    "num_players": 3,
    "score_penalty": 2.0,
    "observe_other_player_indirect": False,
    "mean_reward": 1.0,
    "reward_refunded": 10,
    "final_reward": 100,
    "score_per_unknown": 5.0,
    "action_reward_decay": 1.0,
    "old_reward": False,
    "render_mode": "human",
}

model_config = {
    "custom_model": TorchActionMaskModel,
    # Add the following keys:
    # "fcnet_hiddens": [1024, 1024, 1024, 512, 512],
    "fcnet_activation": "tanh",
}

param_space = {
    "lr": tune.grid_search([0.0001, 0.001, 0.01]),  # Learning rate options
    "model": tune.grid_search([{"custom_model": TorchActionMaskModel, "fcnet_activation": "relu"}, {"custom_model": TorchActionMaskModel, "fcnet_activation": "tanh"}])
}

def env_creator(config):
    return PettingZooEnv(skyjo_env(**config))

register_env("skyjo", env_creator)

test_env = env_creator(skyjo_config)
obs_space = test_env.observation_space
act_space = test_env.action_space

def policy_mapping_fn(agent_id, _, **kwargs):
    return "policy_" + str(agent_id) #int(agent_id.split("_")[-1])

config = (
    PPOConfig()
    .training()#model=model_config, )
    .environment("skyjo", env_config=skyjo_config)
    .framework('torch')
    .callbacks(SkyjoLoggingCallbacks)
    #.callbacks(RewardDecayCallback)
    .env_runners(num_env_runners=5)
    .rollouts(num_rollout_workers=20, num_envs_per_worker=1)
    .resources(num_gpus=1)
    .multi_agent(
        policies={
            "policy_0": (None, obs_space[0], act_space[0], {"entropy_coeff":0.03}),
            "policy_1": (None, obs_space[1], act_space[1], {"entropy_coeff":0.03}),
            "policy_2": (None, obs_space[2], act_space[2], {"entropy_coeff":0.03})
        },
        policy_mapping_fn=policy_mapping_fn,#(lambda agent_id, *args, **kwargs: agent_id),
    )
    .evaluation(evaluation_num_env_runners=0)
    .debugging(log_level="INFO")
    .api_stack(
        enable_rl_module_and_learner=False,
        # enable_env_runner_and_connector_v2=True,
    )
    # .training()
    #     lr = ,
    # )
)

storage_path = os.path.join(os.getcwd(), "results")

tuner = tune.Tuner(
    trainable="PPO",
    param_space={**config.to_dict(), **param_space},
    run_config=train.RunConfig(
        stop=MaximumIterationStopper(100),
        storage_path=storage_path,
    ),
)
# Out:
# 2025-01-05 18:59:05,641	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# 2025-01-05 18:59:05,642	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_envs_per_worker)` has been deprecated. Use `AlgorithmConfig.env_runners(num_envs_per_env_runner)` instead. This will raise an error in the future!

# %%
# 5, 20, 1, num_cpus_per_worker=2
tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-05 19:08:12</td></tr>
# <tr><td>Running for: </td><td>00:09:05.52        </td></tr>
# <tr><td>Memory:      </td><td>24.2/31.3 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 21.0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc                </th><th style="text-align: right;">    lr</th><th>model               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_skyjo_c1c38_00000</td><td>RUNNING </td><td>192.168.0.236:25895</td><td style="text-align: right;">0.0001</td><td>{&#x27;custom_model&#x27;_5080</td><td style="text-align: right;">    93</td><td style="text-align: right;">         518.482</td><td style="text-align: right;">372000</td><td style="text-align: right;">                   20</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_skyjo_c1c38_00001</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.001 </td><td>{&#x27;custom_model&#x27;_a4c0</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">                     </td><td style="text-align: right;"> </td><td style="text-align: right;"> </td></tr>
# <tr><td>PPO_skyjo_c1c38_00002</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.01  </td><td>{&#x27;custom_model&#x27;_9940</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">                     </td><td style="text-align: right;"> </td><td style="text-align: right;"> </td></tr>
# <tr><td>PPO_skyjo_c1c38_00003</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.0001</td><td>{&#x27;custom_model&#x27;_4200</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">                     </td><td style="text-align: right;"> </td><td style="text-align: right;"> </td></tr>
# <tr><td>PPO_skyjo_c1c38_00004</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.001 </td><td>{&#x27;custom_model&#x27;_3280</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">                     </td><td style="text-align: right;"> </td><td style="text-align: right;"> </td></tr>
# <tr><td>PPO_skyjo_c1c38_00005</td><td>PENDING </td><td>                   </td><td style="text-align: right;">0.01  </td><td>{&#x27;custom_model&#x27;_bd40</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">      </td><td style="text-align: right;">                     </td><td style="text-align: right;"> </td><td style="text-align: right;"> </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>

# %%
# 10, 10, 1
tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-05 16:25:44</td></tr>
# <tr><td>Running for: </td><td>00:28:51.35        </td></tr>
# <tr><td>Memory:      </td><td>23.7/31.3 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 11.0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                 </th><th style="text-align: right;">    lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_skyjo_4d094_00000</td><td>TERMINATED</td><td>192.168.0.236:365195</td><td style="text-align: right;">0.0001</td><td style="text-align: right;">   100</td><td style="text-align: right;">         560.817</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   10</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_skyjo_4d094_00001</td><td>TERMINATED</td><td>192.168.0.236:367970</td><td style="text-align: right;">0.001 </td><td style="text-align: right;">   100</td><td style="text-align: right;">         555.672</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   10</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_skyjo_4d094_00002</td><td>TERMINATED</td><td>192.168.0.236:371106</td><td style="text-align: right;">0.01  </td><td style="text-align: right;">   100</td><td style="text-align: right;">         564.558</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   10</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# 2025-01-05 16:25:44,944	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35' in 0.0291s.
# 2025-01-05 16:25:45,136	INFO tune.py:1041 -- Total run time: 1731.56 seconds (1731.32 seconds for the tuning loop).
# ResultGrid<[
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.4883952), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.908790166450268), 'policy_loss': np.float64(-0.08722403675712871), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(4.9208511005748404e-05), 'kl': np.float64(0.019722942662603403), 'entropy': np.float64(0.7985077326947992), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.63636363636364), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.8336459), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.84418970743815), 'policy_loss': np.float64(-0.08045415789679145), 'vf_loss': np.float64(9.935518657799923), 'vf_explained_var': np.float64(-2.7771068341804274e-05), 'kl': np.float64(0.014461034729968313), 'entropy': np.float64(0.8505516232866229), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.18181818181819), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5830363), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.908456579844158), 'policy_loss': np.float64(-0.08440271751976318), 'vf_loss': np.float64(9.992629741899895), 'vf_explained_var': np.float64(-0.00025706435694839016), 'kl': np.float64(0.020344569000892352), 'entropy': np.float64(0.6789754177584792), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.81818181818181), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399980, 'num_agent_steps_trained': 399980}, 'env_runners': {'episode_reward_max': np.float64(-4496.0), 'episode_reward_min': np.float64(-104306.0), 'episode_reward_mean': np.float64(-16196.33), 'episode_len_mean': np.float64(158.8), 'episode_media': {}, 'episodes_timesteps_total': 15880, 'policy_reward_min': {'policy_1': np.float64(-45267.0), 'policy_2': np.float64(-29849.0), 'policy_0': np.float64(-29190.0)}, 'policy_reward_max': {'policy_1': np.float64(-484.0), 'policy_2': np.float64(1790.0), 'policy_0': np.float64(-283.0)}, 'policy_reward_mean': {'policy_1': np.float64(-5959.66), 'policy_2': np.float64(-4072.88), 'policy_0': np.float64(-6163.79)}, 'custom_metrics': {'final_sum_of_revealed_cards_1_mean': np.float64(45.81), 'final_sum_of_revealed_cards_1_min': np.int64(5), 'final_sum_of_revealed_cards_1_max': np.int64(76), 'n_hidden_cards_1_mean': np.float64(1.3), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(6), 'final_sum_of_revealed_cards_2_mean': np.float64(27.38), 'final_sum_of_revealed_cards_2_min': np.int64(-5), 'final_sum_of_revealed_cards_2_max': np.int64(63), 'n_hidden_cards_2_mean': np.float64(4.38), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(9), 'final_sum_of_revealed_cards_0_mean': np.float64(44.51), 'final_sum_of_revealed_cards_0_min': np.int64(15), 'final_sum_of_revealed_cards_0_max': np.int64(84), 'n_hidden_cards_0_mean': np.float64(1.18), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(6)}, 'hist_stats': {'episode_reward': [np.float64(-14312.0), np.float64(-4688.0), np.float64(-10859.0), np.float64(-24620.0), np.float64(-7237.0), np.float64(-18649.0), np.float64(-9843.0), np.float64(-14010.0), np.float64( ...
#     path='/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00000_0_lr=0.0001_2025-01-05_15-56-53',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00000_0_lr=0.0001_2025-01-05_15-56-53/checkpoint_000000)
#   ),
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.5129045), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.8223119504524), 'policy_loss': np.float64(-0.15883904595605353), 'vf_loss': np.float64(9.99174597191088), 'vf_explained_var': np.float64(6.194403677275687e-05), 'kl': np.float64(0.013478832995998814), 'entropy': np.float64(1.3767151843417775), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.54545454545455), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.53635746), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.823704644405481), 'policy_loss': np.float64(-0.16721390337034156), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(-0.00011633706815315015), 'kl': np.float64(0.014754766788509038), 'entropy': np.float64(1.4231540528210727), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.45454545454545), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.5284757), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.820249369650176), 'policy_loss': np.float64(-0.1691343320646521), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(9.971495830651485e-06), 'kl': np.float64(0.014545034164432773), 'entropy': np.float64(1.4583891893878127), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.54545454545455), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399981, 'num_agent_steps_trained': 399981}, 'env_runners': {'episode_reward_max': np.float64(-5834.0), 'episode_reward_min': np.float64(-41272.0), 'episode_reward_mean': np.float64(-16312.31), 'episode_len_mean': np.float64(122.64), 'episode_media': {}, 'episodes_timesteps_total': 12264, 'policy_reward_min': {'policy_2': np.float64(-15866.0), 'policy_0': np.float64(-18040.0), 'policy_1': np.float64(-13279.0)}, 'policy_reward_max': {'policy_2': np.float64(-90.0), 'policy_0': np.float64(-380.0), 'policy_1': np.float64(-777.0)}, 'policy_reward_mean': {'policy_2': np.float64(-5246.46), 'policy_0': np.float64(-5641.64), 'policy_1': np.float64(-5424.21)}, 'custom_metrics': {'final_sum_of_revealed_cards_2_mean': np.float64(50.77), 'final_sum_of_revealed_cards_2_min': np.int64(10), 'final_sum_of_revealed_cards_2_max': np.int64(88), 'n_hidden_cards_2_mean': np.float64(1.12), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(4), 'final_sum_of_revealed_cards_0_mean': np.float64(53.89), 'final_sum_of_revealed_cards_0_min': np.int64(21), 'final_sum_of_revealed_cards_0_max': np.int64(97), 'n_hidden_cards_0_mean': np.float64(0.46), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(3), 'final_sum_of_revealed_cards_1_mean': np.float64(47.75), 'final_sum_of_revealed_cards_1_min': np.int64(16), 'final_sum_of_revealed_cards_1_max': np.int64(90), 'n_hidden_cards_1_mean': np.float64(1.86), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(5)}, 'hist_stats': {'episode_reward': [np.float64(-13890.0), np.float64(-10880.0), np.float64(-15181.0), np.float64(-20993.0), np.float64(-12002.0), np.float64 ...
#     path='/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00001_1_lr=0.0010_2025-01-05_15-56-53',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00001_1_lr=0.0010_2025-01-05_15-56-53/checkpoint_000000)
#   ),
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(3.5297792), 'cur_kl_coeff': np.float64(4.865487670898439), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(10.023274791601933), 'policy_loss': np.float64(0.001448241677699667), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(1.806201356830019e-08), 'kl': np.float64(0.008211839551917519), 'entropy': np.float64(0.6042676681821997), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.27272727272727), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5015676), 'cur_kl_coeff': np.float64(1.9483926152810453), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(10.01004245931452), 'policy_loss': np.float64(0.0023268869397174), 'vf_loss': np.float64(9.999668083768903), 'vf_explained_var': np.float64(-4.678061514189749e-08), 'kl': np.float64(0.009604003134397014), 'entropy': np.float64(0.3554962076924064), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.27272727272727), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.09608605), 'cur_kl_coeff': np.float64(0.22806973457336427), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(9.986134558012992), 'policy_loss': np.float64(-0.0005215302307271596), 'vf_loss': np.float64(9.986888700543028), 'vf_explained_var': np.float64(-5.779844341856061e-09), 'kl': np.float64(0.0007818921085551913), 'entropy': np.float64(0.013698535689124556), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.0909090909091), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399980, 'num_agent_steps_trained': 399980}, 'env_runners': {'episode_reward_max': np.float64(-12275.0), 'episode_reward_min': np.float64(-2333850.0), 'episode_reward_mean': np.float64(-207541.15), 'episode_len_mean': np.float64(1280.32), 'episode_media': {}, 'episodes_timesteps_total': 128032, 'policy_reward_min': {'policy_1': np.float64(-606098.0), 'policy_2': np.float64(-721134.0), 'policy_0': np.float64(-1040486.0)}, 'policy_reward_max': {'policy_1': np.float64(-1019.0), 'policy_2': np.float64(-2159.0), 'policy_0': np.float64(-2718.0)}, 'policy_reward_mean': {'policy_1': np.float64(-75150.46), 'policy_2': np.float64(-64045.34), 'policy_0': np.float64(-68345.35)}, 'custom_metrics': {'final_sum_of_revealed_cards_1_mean': np.float64(51.03), 'final_sum_of_revealed_cards_1_min': np.int64(6), 'final_sum_of_revealed_cards_1_max': np.int64(90), 'n_hidden_cards_1_mean': np.float64(0.59), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(5), 'final_sum_of_revealed_cards_2_mean': np.float64(49.98), 'final_sum_of_revealed_cards_2_min': np.int64(17), 'final_sum_of_revealed_cards_2_max': np.int64(93), 'n_hidden_cards_2_mean': np.float64(1.56), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(6), 'final_sum_of_revealed_cards_0_mean': np.float64(46.04), 'final_sum_of_revealed_cards_0_min': np.int64(9), 'final_sum_of_revealed_cards_0_max': np.int64(83), 'n_hidden_cards_0_mean': np.float64(1.91), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(5)}, 'hist_stats': {'episode_reward': [np.float64(-58638.0), np.float64(-46807.0), np.float64(-22999.0), np.float64(-27108.0), np.float64(-44252.0), np.float64(-33837.0), np.f ...
#     path='/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00002_2_lr=0.0100_2025-01-05_15-56-53',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/Documents/SharedDocuments/Uni/TU/3.Semester/AdvRL/SkyjoAI/results/PPO_2025-01-05_15-56-35/PPO_skyjo_4d094_00002_2_lr=0.0100_2025-01-05_15-56-53/checkpoint_000000)
#   )
# ]>

# %%
# 5, 20, 1
tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-01-05 15:23:37</td></tr>
# <tr><td>Running for: </td><td>00:27:52.97        </td></tr>
# <tr><td>Memory:      </td><td>26.9/31.3 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 21.0/24 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc                 </th><th style="text-align: right;">    lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_
# sample_reqs</th><th style="text-align: right;">  num_remote_worker_re
# starts</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_skyjo_c267c_00000</td><td>TERMINATED</td><td>192.168.0.236:352221</td><td style="text-align: right;">0.0001</td><td style="text-align: right;">   100</td><td style="text-align: right;">         546.921</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   20</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_skyjo_c267c_00001</td><td>TERMINATED</td><td>192.168.0.236:355087</td><td style="text-align: right;">0.001 </td><td style="text-align: right;">   100</td><td style="text-align: right;">         536.238</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   20</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# <tr><td>PPO_skyjo_c267c_00002</td><td>TERMINATED</td><td>192.168.0.236:357834</td><td style="text-align: right;">0.01  </td><td style="text-align: right;">   100</td><td style="text-align: right;">         527.571</td><td style="text-align: right;">400000</td><td style="text-align: right;">                   20</td><td style="text-align: right;">0</td><td style="text-align: right;">0</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2025-01-05 15:23:37,998	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/henry/ray_results/PPO_2025-01-05_14-55-44' in 0.0561s.
# 2025-01-05 15:23:38,467	INFO tune.py:1041 -- Total run time: 1673.44 seconds (1672.91 seconds for the tuning loop).
# ResultGrid<[
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.1971877), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.89376881050341), 'policy_loss': np.float64(-0.0994886607032227), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(8.851127191023393e-05), 'kl': np.float64(0.0167132967919315), 'entropy': np.float64(0.7888238800294471), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.9090909090909), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.0731082), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.868592291167289), 'policy_loss': np.float64(-0.0952072550711984), 'vf_loss': np.float64(9.974530217141815), 'vf_explained_var': np.float64(-0.00037307883753921045), 'kl': np.float64(0.014372431420027473), 'entropy': np.float64(0.8427588979403178), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.54545454545455), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.460783), 'cur_kl_coeff': np.float64(1.0125), 'cur_lr': np.float64(0.0001), 'total_loss': np.float64(9.865067938602332), 'policy_loss': np.float64(-0.07879630344863417), 'vf_loss': np.float64(9.950836993708755), 'vf_explained_var': np.float64(-0.00018602483200304436), 'kl': np.float64(0.012339109387115303), 'entropy': np.float64(0.6488703359257091), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(122.0909090909091), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399960, 'num_agent_steps_trained': 399960}, 'env_runners': {'episode_reward_max': np.float64(-2969.0), 'episode_reward_min': np.float64(-95820.0), 'episode_reward_mean': np.float64(-23135.39), 'episode_len_mean': np.float64(237.38), 'episode_media': {}, 'episodes_timesteps_total': 23738, 'policy_reward_min': {'policy_2': np.float64(-29866.0), 'policy_0': np.float64(-25965.0), 'policy_1': np.float64(-86950.0)}, 'policy_reward_max': {'policy_2': np.float64(2280.0), 'policy_0': np.float64(2723.0), 'policy_1': np.float64(1077.0)}, 'policy_reward_mean': {'policy_2': np.float64(-6858.3), 'policy_0': np.float64(-8664.6), 'policy_1': np.float64(-7612.49)}, 'custom_metrics': {'final_sum_of_revealed_cards_2_mean': np.float64(29.82), 'final_sum_of_revealed_cards_2_min': np.int64(-5), 'final_sum_of_revealed_cards_2_max': np.int64(73), 'n_hidden_cards_2_mean': np.float64(3.42), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(9), 'final_sum_of_revealed_cards_0_mean': np.float64(46.23), 'final_sum_of_revealed_cards_0_min': np.int64(2), 'final_sum_of_revealed_cards_0_max': np.int64(81), 'n_hidden_cards_0_mean': np.float64(0.14), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(3), 'final_sum_of_revealed_cards_1_mean': np.float64(31.16), 'final_sum_of_revealed_cards_1_min': np.int64(2), 'final_sum_of_revealed_cards_1_max': np.int64(67), 'n_hidden_cards_1_mean': np.float64(3.06), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(7)}, 'hist_stats': {'episode_reward': [np.float64(-34822.0), np.float64(-16902.0), np.float64(-21581.0), np.float64(-10987.0), np.float64(-4887.0), np.float64(-47193.0), np.float64(-48437.0), np.float64(-14469.0), np.float64(-10645.0 ...
#     path='/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00000_0_lr=0.0001_2025-01-05_14-55-45',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00000_0_lr=0.0001_2025-01-05_14-55-45/checkpoint_000000)
#   ),
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.34936407), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.909763558705647), 'policy_loss': np.float64(-0.0995096569669179), 'vf_loss': np.float64(9.999999913302334), 'vf_explained_var': np.float64(-1.6785571069428416e-05), 'kl': np.float64(0.015786411954093527), 'entropy': np.float64(0.8896714526595492), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.9090909090909), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.3809288), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.891015021006266), 'policy_loss': np.float64(-0.1143470986379367), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(2.6370539809718274e-07), 'kl': np.float64(0.014547804508787742), 'entropy': np.float64(0.9259874576872046), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.54545454545455), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.58666795), 'cur_kl_coeff': np.float64(2.2781249999999993), 'cur_lr': np.float64(0.0010000000000000002), 'total_loss': np.float64(9.846188848668879), 'policy_loss': np.float64(-0.14885604876573338), 'vf_loss': np.float64(10.0), 'vf_explained_var': np.float64(2.7378400166829425e-06), 'kl': np.float64(0.015915141608836066), 'entropy': np.float64(1.3737262899225409), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.18181818181819), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399960, 'num_agent_steps_trained': 399960}, 'env_runners': {'episode_reward_max': np.float64(-5132.0), 'episode_reward_min': np.float64(-146195.0), 'episode_reward_mean': np.float64(-28483.93), 'episode_len_mean': np.float64(197.84), 'episode_media': {}, 'episodes_timesteps_total': 19784, 'policy_reward_min': {'policy_0': np.float64(-44648.0), 'policy_1': np.float64(-51022.0), 'policy_2': np.float64(-50525.0)}, 'policy_reward_max': {'policy_0': np.float64(-791.0), 'policy_1': np.float64(55.0), 'policy_2': np.float64(-1360.0)}, 'policy_reward_mean': {'policy_0': np.float64(-9325.34), 'policy_1': np.float64(-9072.45), 'policy_2': np.float64(-10086.14)}, 'custom_metrics': {'final_sum_of_revealed_cards_0_mean': np.float64(48.72), 'final_sum_of_revealed_cards_0_min': np.int64(7), 'final_sum_of_revealed_cards_0_max': np.int64(93), 'n_hidden_cards_0_mean': np.float64(1.3), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(4), 'final_sum_of_revealed_cards_1_mean': np.float64(41.82), 'final_sum_of_revealed_cards_1_min': np.int64(12), 'final_sum_of_revealed_cards_1_max': np.int64(82), 'n_hidden_cards_1_mean': np.float64(2.46), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(5), 'final_sum_of_revealed_cards_2_mean': np.float64(51.07), 'final_sum_of_revealed_cards_2_min': np.int64(25), 'final_sum_of_revealed_cards_2_max': np.int64(101), 'n_hidden_cards_2_mean': np.float64(0.66), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(4)}, 'hist_stats': {'episode_reward': [np.float64(-26741.0), np.float64(-14069.0), np.float64(-14590.0), np.float64(-12780.0), np.float64(-74267.0), np.fl ...
#     path='/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00001_1_lr=0.0010_2025-01-05_14-55-45',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00001_1_lr=0.0010_2025-01-05_14-55-45/checkpoint_000000)
#   ),
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'policy_1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.231994), 'cur_kl_coeff': np.float64(2.736836814880371), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(9.990125719706217), 'policy_loss': np.float64(0.0004621513865210793), 'vf_loss': np.float64(9.974448284958347), 'vf_explained_var': np.float64(-9.031006784150095e-09), 'kl': np.float64(0.008674674509799815), 'entropy': np.float64(0.28419858849409857), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.36363636363636), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_0': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(4.220043), 'cur_kl_coeff': np.float64(5.766503906250001), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(10.02837300156102), 'policy_loss': np.float64(0.0045641337623678595), 'vf_loss': np.float64(9.983814369548451), 'vf_explained_var': np.float64(2.7093020352450285e-09), 'kl': np.float64(0.010548891093110963), 'entropy': np.float64(0.6945238696806358), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(120.9090909090909), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}, 'policy_2': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(0.86850494), 'cur_kl_coeff': np.float64(2.1624389648437505), 'cur_lr': np.float64(0.01), 'total_loss': np.float64(10.02004224314834), 'policy_loss': np.float64(0.005188885220912088), 'vf_loss': np.float64(9.990832825863), 'vf_explained_var': np.float64(-5.418604070490057e-09), 'kl': np.float64(0.012778465158915038), 'entropy': np.float64(0.12040360127434586), 'entropy_coeff': np.float64(0.030000000000000006)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(121.36363636363636), 'num_grad_updates_lifetime': np.float64(32835.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(164.5)}}, 'num_env_steps_sampled': 400000, 'num_env_steps_trained': 400000, 'num_agent_steps_sampled': 399960, 'num_agent_steps_trained': 399960}, 'env_runners': {'episode_reward_max': np.float64(-8881.0), 'episode_reward_min': np.float64(-1597556.0), 'episode_reward_mean': np.float64(-205871.7), 'episode_len_mean': np.float64(1331.76), 'episode_media': {}, 'episodes_timesteps_total': 133176, 'policy_reward_min': {'policy_2': np.float64(-606894.0), 'policy_0': np.float64(-523470.0), 'policy_1': np.float64(-533255.0)}, 'policy_reward_max': {'policy_2': np.float64(-1834.0), 'policy_0': np.float64(-1507.0), 'policy_1': np.float64(-1964.0)}, 'policy_reward_mean': {'policy_2': np.float64(-68235.3), 'policy_0': np.float64(-71075.39), 'policy_1': np.float64(-66561.01)}, 'custom_metrics': {'final_sum_of_revealed_cards_2_mean': np.float64(47.68), 'final_sum_of_revealed_cards_2_min': np.int64(0), 'final_sum_of_revealed_cards_2_max': np.int64(82), 'n_hidden_cards_2_mean': np.float64(1.17), 'n_hidden_cards_2_min': np.int64(0), 'n_hidden_cards_2_max': np.int64(4), 'final_sum_of_revealed_cards_0_mean': np.float64(49.11), 'final_sum_of_revealed_cards_0_min': np.int64(12), 'final_sum_of_revealed_cards_0_max': np.int64(90), 'n_hidden_cards_0_mean': np.float64(0.66), 'n_hidden_cards_0_min': np.int64(0), 'n_hidden_cards_0_max': np.int64(5), 'final_sum_of_revealed_cards_1_mean': np.float64(46.33), 'final_sum_of_revealed_cards_1_min': np.int64(1), 'final_sum_of_revealed_cards_1_max': np.int64(86), 'n_hidden_cards_1_mean': np.float64(1.66), 'n_hidden_cards_1_min': np.int64(0), 'n_hidden_cards_1_max': np.int64(5)}, 'hist_stats': {'episode_reward': [np.float64(-19195.0), np.float64(-17705.0), np.float64(-29456.0), np.float64(-21936.0), np.float64(-27872.0), np.float64(-25703.0), n ...
#     path='/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00002_2_lr=0.0100_2025-01-05_14-55-45',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/home/henry/ray_results/PPO_2025-01-05_14-55-44/PPO_skyjo_c267c_00002_2_lr=0.0100_2025-01-05_14-55-45/checkpoint_000000)
#   )
# ]>
